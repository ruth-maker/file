# %%
# %store -r raw_info

# %%
raw_info
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
locationzip =raw_info.zipcode
locationzip
# Out:
# 0        98178
# 1        98125
# 2        98028
# 3        98136
# 4        98074
#          ...
# 21592    98103
# 21593    98146
# 21594    98144
# 21595    98027
# 21596    98144
# Name: zipcode, Length: 21597, dtype: int64

# %%
index = []
select = []
for i,x in enumerate(raw_info.lat):
    if x == 47.618:index.append(i)
    if x == 47.528:index.append(i)
    if x == 47.502:index.append(i)  
    if x == 47.530:index.append(i)
    if x == 47.567:index.append(i)
    if x == 47.733:index.append(i)   
    if x == 47.648:index.append(i)

index
for i,x in enumerate(index):
    print(x,locationzip[x])
    select.append(locationzip[x])
# Out:
# 1080 98178
# 1358 98199
# 2130 98106
# 3256 98072
# 4411 98075
# 4979 98019
# 6037 98116
# 6048 98106
# 6165 98178
# 6184 98108
# 7376 98199
# 8500 98056
# 8794 98136
# 9246 98065
# 10088 98040
# 10519 98029
# 10637 98006
# 10707 98024
# 10734 98106
# 11586 98059
# 11734 98034
# 12201 98118
# 13651 98056
# 13699 98029
# 13904 98119
# 15269 98199
# 15361 98199
# 15715 98040
# 15782 98034
# 15930 98006
# 16053 98006
# 16211 98146
# 16563 98106
# 17342 98072
# 17669 98052
# 17967 98126
# 18037 98108
# 18290 98199
# 20047 98059
# 20114 98118
# 20243 98118
# 20288 98122
# 20300 98027
# 20404 98027
# 20444 98004
# 20515 98199
# [1080,
#  1358,
#  2130,
#  3256,
#  4411,
#  4979,
#  6037,
#  6048,
#  6165,
#  6184,
#  7376,
#  8500,
#  8794,
#  9246,
#  10088,
#  10519,
#  10637,
#  10707,
#  10734,
#  11586,
#  11734,
#  12201,
#  13651,
#  13699,
#  13904,
#  15269,
#  15361,
#  15715,
#  15782,
#  15930,
#  16053,
#  16211,
#  16563,
#  17342,
#  17669,
#  17967,
#  18037,
#  18290,
# ...

# %%
[i for i in select if i in locationzip]
# Out:
# []

# %%
raw_info.iloc[[]]
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 1080   7567600045   8/27/2014   825000.0         2       1.00         1150
# 1358   6821600390    1/8/2015   815000.0         3       2.00         2310
# 2130   2113701200   9/12/2014   250000.0         2       1.00          670
# 3256   1137301780  11/26/2014   580000.0         3       2.50         2180
# 4411   3295610490    5/4/2015   911000.0         4       3.25         3526
# 4979   1443550020    5/6/2015   570000.0         4       2.50         2640
# 6037    952001735   10/4/2014   750000.0         4       1.75         2100
# 6048   4302201045   5/28/2014   150000.0         3       1.00          820
# 6165   3810000020   3/18/2015   352000.0         4       1.50         1440
# 6184   5679501310  10/30/2014   445000.0         3       1.75         2110
# 7376   2770600795    3/2/2015   585000.0         4       1.75         2500
# ...

# %%
# %store -r Prediction8 
# %store -r Prediction7 
# %store -r Prediction5 
# %store -r Prediction4
# %store -r Prediction3
# %store -r Prediction2
# %store -r Prediction1
# %store -r Prediction

# %%
East_prediction_sqft_lot= Prediction8
East_prediction_sqft_lot
# Out:
#       Amount_of_sqft_lot                    Prediction Actual Price
# 0                   5000  Between: $201,558 - $939,876     $604,000
# 1                   5000  Between: $201,558 - $939,876     $650,000
# 2                   5000  Between: $201,558 - $939,876     $207,950
# 3                   5000  Between: $201,558 - $939,876     $615,000
# 4                   5000  Between: $201,558 - $939,876     $275,000
# ...                  ...                           ...          ...
# 8344               11533  Between: $201,558 - $939,876   $1,150,000
# 8345                9532  Between: $201,558 - $939,876     $711,000
# 8346                1833  Between: $201,558 - $939,876     $798,500
# 8347               14564  Between: $201,558 - $939,876     $308,500
# 8348               16619  Between: $201,558 - $939,876   $1,120,000
#
# [8284 rows x 3 columns]

# %%
East_prediction_sqft_living= Prediction7
East_prediction_sqft_living
# Out:
#       Amount_of_sqft_Living                     Prediction Actual Price
# 0                      1300    Between: $336,638- $724,824     $236,000
# 1                      1300    Between: $336,638- $724,824     $378,000
# 2                      1300    Between: $336,638- $724,824     $331,000
# 3                      1300    Between: $336,638- $724,824     $445,950
# 4                      1300    Between: $336,638- $724,824     $315,500
# ...                     ...                            ...          ...
# 8344                   4133  Between: $710,003- $1,514,226     $979,500
# 8345                   2134    Between: $336,638- $724,824     $611,000
# 8346                   6260  Between: $710,003- $1,514,226   $1,180,000
# 8347                   2518    Between: $336,638- $724,824     $643,000
# 8348                   6980  Between: $710,003- $1,514,226   $3,100,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Condition_Level=Prediction5
East_prediction_Condition_Level
# Out:
#        Condition Level                    Prediction Actual Price
# 0                    3  Between: $299,999 - $990,999     $538,000
# 1                    3  Between: $299,999 - $990,999   $1,230,000
# 2                    3  Between: $299,999 - $990,999     $257,500
# 3                    3  Between: $299,999 - $990,999     $291,850
# 4                    3  Between: $299,999 - $990,999     $229,500
# ...                ...                           ...          ...
# 11573                1  Between: $280,000 - $980,000     $432,500
# 11574                1  Between: $280,000 - $980,000      $78,000
# 11575                1  Between: $280,000 - $980,000      $81,000
# 11576                1  Between: $280,000 - $980,000     $380,000
# 11577                1  Between: $280,000 - $980,000     $575,000
#
# [11578 rows x 3 columns]

# %%
East_prediction_Year_Renoveted=Prediction4
East_prediction_Year_Renoveted
# Out:
#       Year Renoveted                      Prediction Actual Price
# 0                0.0  Between: $263,411 - $1,322,038   $1,230,000
# 1                0.0  Between: $263,411 - $1,322,038     $257,500
# 2                0.0  Between: $263,411 - $1,322,038     $291,850
# 3                0.0  Between: $263,411 - $1,322,038     $229,500
# 4                0.0  Between: $263,411 - $1,322,038     $323,000
# ...              ...                             ...          ...
# 9493          1967.0  Between: $263,411 - $1,322,038     $290,000
# 9494          1954.0  Between: $263,411 - $1,322,038     $900,000
# 9495          1946.0  Between: $263,411 - $1,322,038     $550,000
# 9496          1953.0  Between: $263,411 - $1,322,038     $247,500
# 9497          1959.0  Between: $263,411 - $1,322,038     $397,500
#
# [9498 rows x 3 columns]

# %%
East_prediction_Year_Built=Prediction3
East_prediction_Year_Built
# Out:
#       Year Built                      Prediction Actual Price
# 0           2014   Between: $359,232- $1,216,998     $453,246
# 1           2014   Between: $359,232- $1,216,998     $802,541
# 2           2014   Between: $359,232- $1,216,998   $1,220,000
# 3           2014   Between: $359,232- $1,216,998   $1,680,000
# 4           2014   Between: $359,232- $1,216,998     $599,950
# ...          ...                             ...          ...
# 8344        1934  Between: $361,699 - $1,003,203     $750,000
# 8345        1934  Between: $361,699 - $1,003,203     $275,000
# 8346        1934  Between: $361,699 - $1,003,203     $529,000
# 8347        1934  Between: $361,699 - $1,003,203   $2,030,000
# 8348        1934  Between: $361,699 - $1,003,203     $240,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Amount_of_Floors=Prediction2
East_prediction_Amount_of_Floors
# Out:
#       Amount of Floors                      Prediction Actual Price
# 0                  1.0  Between: $340,198 - $1,316,791     $221,900
# 1                  1.0  Between: $340,198 - $1,316,791     $604,000
# 2                  1.0  Between: $340,198 - $1,316,791     $229,500
# 3                  1.0  Between: $340,198 - $1,316,791   $2,000,000
# 4                  1.0  Between: $340,198 - $1,316,791     $550,000
# ...                ...                             ...          ...
# 8344               2.5  Between: $359,998 - $1,189,995     $645,000
# 8345               2.5  Between: $359,998 - $1,189,995     $680,000
# 8346               2.5  Between: $359,998 - $1,189,995     $669,950
# 8347               2.5  Between: $359,998 - $1,189,995     $453,000
# 8348               3.5  Between: $359,998 - $1,189,995     $479,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Amount_of_Bathrooms=Prediction1
East_prediction_Amount_of_Bathrooms
# Out:
#       Amount of Bathrooms                      Prediction Actual Price
# 0                    2.50    Between: $200,002 - $550,008     $719,000
# 1                    2.50    Between: $200,002 - $550,008     $580,500
# 2                    2.50    Between: $200,002 - $550,008     $605,000
# 3                    2.50    Between: $200,002 - $550,008     $488,000
# 4                    2.50    Between: $200,002 - $550,008     $345,000
# ...                   ...                             ...          ...
# 8344                 0.50    Between: $200,002 - $550,008     $255,000
# 8345                 6.25  Between: $536,188 - $1,612,980   $3,300,000
# 8346                 6.75    Between: $200,002 - $550,008   $4,670,000
# 8347                 6.50  Between: $536,188 - $1,612,980   $1,180,000
# 8348                 6.50  Between: $536,188 - $1,612,980   $2,240,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Amount_of_Bedrooms=Prediction
East_prediction_Amount_of_Bedrooms
# Out:
#       Amount of Bedrooms                      Prediction Actual Price
# 0                      3   Between: $210,001  - $633,508     $221,900
# 1                      3   Between: $210,001  - $633,508     $229,500
# 2                      3   Between: $210,001  - $633,508     $395,000
# 3                      3   Between: $210,001  - $633,508   $2,000,000
# 4                      3   Between: $210,001  - $633,508     $937,000
# ...                  ...                             ...          ...
# 8344                   8  Between: $351,398 - $1,607,982     $430,000
# 8345                   8  Between: $351,398 - $1,607,982     $575,000
# 8346                  10  Between: $351,398 - $1,607,982   $1,150,000
# 8347                  10  Between: $351,398 - $1,607,982     $650,000
# 8348                  11  Between: $351,398 - $1,607,982     $520,000
#
# [8349 rows x 3 columns]
