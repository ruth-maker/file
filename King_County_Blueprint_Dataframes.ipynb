# %%
import pandas as pd

# %%
# %store -r raw_info

# %%
raw_info
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
locationzip =raw_info.zipcode
locationzip
# Out:
# 0        98178
# 1        98125
# 2        98028
# 3        98136
# 4        98074
#          ...
# 21592    98103
# 21593    98146
# 21594    98144
# 21595    98027
# 21596    98144
# Name: zipcode, Length: 21597, dtype: int64

# %%
index = []
select = []
for i,x in enumerate(raw_info.lat):
    if x == 47.618:index.append(i)
    if x == 47.528:index.append(i)
    if x == 47.502:index.append(i)  
    if x == 47.530:index.append(i)
    if x == 47.567:index.append(i)
    if x == 47.733:index.append(i)   
    if x == 47.648:index.append(i)

index
for i,x in enumerate(index):
     select.append(locationzip[x])
#len(select)
select
# Out:
# [98178,
#  98199,
#  98106,
#  98072,
#  98075,
#  98019,
#  98116,
#  98106,
#  98178,
#  98108,
#  98199,
#  98056,
#  98136,
#  98065,
#  98040,
#  98029,
#  98006,
#  98024,
#  98106,
#  98059,
#  98034,
#  98118,
#  98056,
#  98029,
#  98119,
#  98199,
#  98199,
#  98040,
#  98034,
#  98006,
#  98006,
#  98146,
#  98106,
#  98072,
#  98052,
#  98126,
#  98108,
#  98199,
#  98059,
#  98118,
#  98118,
#  98122,
#  98027,
#  98027,
#  98004,
#  98199]

# %%
index2 = []
for x,i in enumerate(raw_info.zipcode):
        if i == select[0] : index2.append(x)
        elif i == select[1] : index2.append(x)
        elif i == select[2] : index2.append(x)
        elif i == select[3] : index2.append(x)
        elif i == select[4] : index2.append(x)
        elif i == select[5] : index2.append(x)
        elif i == select[6] : index2.append(x)
        elif i == select[7] : index2.append(x)
        elif i == select[8] : index2.append(x)
        elif i == select[9] : index2.append(x)
        elif i == select[10] : index2.append(x)
        elif i == select[11] : index2.append(x)
        elif i == select[12] : index2.append(x)
        elif i == select[13] : index2.append(x)
        elif i == select[14] : index2.append(x)
        elif i == select[15] : index2.append(x)
        elif i == select[16] : index2.append(x)
        elif i == select[17] : index2.append(x)
        elif i == select[18] : index2.append(x)
        elif i == select[19] : index2.append(x)
        elif i == select[20] : index2.append(x)
        elif i == select[21]: index2.append(x)
        elif i == select[22] : index2.append(x)
        elif i == select[23] : index2.append(x)
        elif i == select[24] : index2.append(x)
        elif i == select[25] : index2.append(x)
        elif i == select[26] : index2.append(x)
        elif i == select[27] : index2.append(x)
        elif i == select[28] : index2.append(x)
        elif i == select[29] : index2.append(x)
        elif i == select[30] : index2.append(x)
        elif i == select[31] : index2.append(x)
        elif i == select[32] : index2.append(x)
        elif i == select[33] : index2.append(x)
        elif i == select[34] : index2.append(x)
        elif i == select[35] : index2.append(x)
        elif i == select[36] : index2.append(x)
        elif i == select[37] : index2.append(x)
        elif i == select[38] : index2.append(x)
        elif i == select[39] : index2.append(x)
        elif i == select[40] : index2.append(x)
        elif i == select[41] : index2.append(x)
        elif i == select[42] : index2.append(x)
        elif i == select[43] : index2.append(x)
        elif i == select[44] : index2.append(x)
        elif i == select[45] : index2.append(x)
len(index2)
# %store index2
# Out:
# Stored 'index2' (list)

# %%
id = []
for i in index2:
    id.append(raw_info.id[i])
len(id)
# Out:
# 8349

# %%
date = []
for i in index2:
    date.append(raw_info.date[i])
len(date)
# Out:
# 8349

# %%
bedrooms = []
for i in index2:
    bedrooms.append(raw_info.bedrooms[i])
len(bedrooms)
# Out:
# 8349

# %%
bathrooms = []
for i in index2:
    bathrooms.append(raw_info.bathrooms[i])
len(bathrooms)
# Out:
# 8349

# %%
sqft_living = []
for i in index2:
    sqft_living.append(raw_info.sqft_living[i])
len(sqft_living)
# Out:
# 8349

# %%
sqft_lot = []
for i in index2:
    sqft_lot.append(raw_info.sqft_lot[i])
len(sqft_lot)
# Out:
# 8349

# %%
floors = []
for i in index2:
    floors.append(raw_info.floors[i])
len(floors)
# Out:
# 8349

# %%
yr_built = []
for i in index2:
    yr_built.append(raw_info.yr_built[i])
len(yr_built)
# Out:
# 8349

# %%
yr_renovated = []
for i in index2:
    yr_renovated.append(raw_info.yr_renovated[i])
len(yr_renovated)
# Out:
# 8349

# %%
condition = []
for i in index2:
    condition.append(raw_info.condition[i])
len(condition)
# Out:
# 8349

# %%
g = []
for i in range(8349):
    g.append('Quantile')

# %%
x = []
for i in range(8349):
    x.append('Regression')

# %%
f = []
for i in range(8349):
    f.append('Predictions')

# %%
house_info = pd.DataFrame({'Id':id,'Date':date,'Bedrooms':bedrooms, 'Bathrooms':bathrooms, 
                           'Floors':floors, 'Year Built':yr_built, 'Year Renoveted':yr_renovated,
            'Condition':condition, 'Sqft_living':sqft_living,'Sqft_lot':sqft_lot,
                          })

# %%
East_predictions = pd.DataFrame({'Id':x,
'Date':f,'Bedrooms':East_prediction_Amount_of_Bedrooms.Prediction,
'Bathrooms':East_prediction_Amount_of_Bathrooms.Prediction, 
'Floors':East_prediction_Amount_of_Floors.Prediction,
'Year Built':East_prediction_Year_Built.Prediction,
'Years Renoveted':East_prediction_Year_Renoveted.Prediction,
'Condition':East_prediction_Condition_Level.Prediction, 
'Sqft_living':East_prediction_sqft_living.Prediction,
'Sqft_lot':East_prediction_sqft_lot.Prediction})

# %%
id1 = []
for i in range(8349):
    id1.append(id[i])
    id1.append(x[i])
len(id1)
# Out:
# 16698

# %%
date1 = []
for i in range(8349):
    date1.append(date[i])
    date1.append(f[i])
len(date1)
# Out:
# 16698

# %%
bedrooms1 = []
for i in range(8349):
    bedrooms1.append(bedrooms[i])
    bedrooms1.append(East_prediction_Amount_of_Bedrooms.Prediction[i])
len(bedrooms1)
# Out:
# 16698

# %%
bathrooms1 = []
for i in range(8349):
    bathrooms1.append(bathrooms[i])
    bathrooms1.append(East_prediction_Amount_of_Bathrooms.Prediction[i])
len(bathrooms1)
# Out:
# 16698

# %%
floors1 = []
for i in range(8349):
    floors1.append(floors[i])
    floors1.append(East_prediction_Amount_of_Floors.Prediction[i])
len(floors1)
# Out:
# 16698

# %%
yr_built1 = []
for i in range(8349):
    yr_built1.append(yr_built[i])
    yr_built1.append(East_prediction_Year_Built.Prediction[i])
len(yr_built1)
# Out:
# 16698

# %%
yr_renovated1 = []
for i in range(8349):
    yr_renovated1.append(yr_renovated[i])
    yr_renovated1.append(East_prediction_Year_Renoveted.Prediction[i])
len(yr_renovated1)
# Out:
# 16698

# %%
condition1 = []
for i in range(8349):
    condition1.append(condition[i])
    condition1.append(East_prediction_Condition_Level.Prediction[i])
len(condition1)
# Out:
# 16698

# %%
sqft_living1 = []
for i in range(8349):
    sqft_living1.append(sqft_living[i])
    sqft_living1.append(East_prediction_sqft_living.Prediction[i])
len(sqft_living1)
# Out:
# 16698

# %%
sqft_lot1 = []
for i in range(8349):
    sqft_lot1.append(sqft_lot[i])
    sqft_lot1.append(East_prediction_sqft_lot.Prediction[i])
len(sqft_lot1)
# Out:
# 16698

# %%
no = []
for i in range(1,8350):
    no.append(i)

# %%
house_info1 = pd.DataFrame({'Id':id1,'Date':date1,'Bedrooms':bedrooms1, 'Bathrooms':bathrooms1, 
                           'Floors':floors1, 'Year Built':yr_built1, 'Year Renoveted':yr_renovated1,
            'Condition':condition1, 'Sqft_living':sqft_living1,'Sqft_lot':sqft_lot1,
                          },
    pd.MultiIndex.from_product([no, ['A', 'B']]),
                          )

# %%
def highlight_max(s, props=''):
    return np.where(s == np.nanmax(s.values), props, '')

# %%
slice_ = idx[idx[:,'B'], :]
df3.style.apply(highlight_max, props='color:red;', axis=1, subset=slice_)\
         .set_properties(**{'background-color': '#ffffb3'}, subset=slice_)

# %%
house_info1
# Out:
#                 Id         Date               Bedrooms              Bathrooms  \
# 1    A  7129300520   10/13/2014                      3                    1.0
#      B  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# 2    A  2487200875    12/9/2014                      4                    3.0
#      B  Regression  Predictions  $351,398 - $1,607,982  $536,188 - $1,612,980
# 3    A  2414600126    4/15/2015                      3                    1.0
# ...            ...          ...                    ...                    ...
# 8347 B  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# 8348 A  6600060120    2/23/2015                      4                    2.5
#      B  Regression  Predictions  $351,398 - $1,607,982    $200,002 - $550,008
# 8349 A   291310100    1/16/2015                      3                    2.5
#      B  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
#
# ...

# %%
idx = pd.IndexSlice
slice_ = idx[idx[:,'r2'], :]
df3.style.apply(highlight_max, props='color:red;', axis=1, subset=slice_)\
         .set_properties(**{'background-color': '#ffffb3'}, subset=slice_)

# %%
index = pd.Index(g)
East_predictions = East_predictions.set_index(index)

# %%
house_info1 = house_info1.head(20)
house_info1
# Out:
#             Id         Date               Bedrooms              Bathrooms  \
# 0   7129300520   10/13/2014                      3                    1.0
# 1   Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# 2   2487200875    12/9/2014                      4                    3.0
# 3   Regression  Predictions  $351,398 - $1,607,982  $536,188 - $1,612,980
# 4   2414600126    4/15/2015                      3                    1.0
# 5   Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# 6   9297300055    1/24/2015                      4                    3.0
# 7   Regression  Predictions  $351,398 - $1,607,982  $536,188 - $1,612,980
# 8   1875500060    7/31/2014                      3                    2.0
# 9   Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# 10  2524049179    8/26/2014                      3                   2.75
# 11  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# ...

# %%
# %store house_info
# %store house_info1
# Out:
# Stored 'house_info' (DataFrame)
# Stored 'house_info1' (DataFrame)

# %%
# %store -r Prediction8 
# %store -r Prediction7 
# %store -r Prediction5 
# %store -r Prediction4
# %store -r Prediction3
# %store -r Prediction2
# %store -r Prediction1
# %store -r Prediction

# %%
East_prediction_sqft_lot= Prediction8
East_prediction_sqft_lot
# Out:
#       Amount_of_sqft_lot           Prediction Actual Price
# 0                   5650  $201,558 - $939,876     $221,900
# 1                   5000  $201,558 - $939,876     $604,000
# 2                   7470  $201,558 - $939,876     $229,500
# 3                   5000  $201,558 - $939,876     $650,000
# 4                  14040  $201,558 - $939,876     $395,000
# ...                  ...                  ...          ...
# 8344                6023  $201,558 - $939,876     $610,685
# 8345                7200  $201,558 - $939,876   $1,010,000
# 8346                1294  $201,558 - $939,876     $475,000
# 8347                5813  $201,558 - $939,876     $400,000
# 8348                2388  $201,558 - $939,876     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_sqft_living= Prediction7
East_prediction_sqft_living
# Out:
#       Amount_of_sqft_Living            Prediction Actual Price
# 0                      1180    $336,638- $724,824     $221,900
# 1                      1960    $336,638- $724,824     $604,000
# 2                      1780    $336,638- $724,824     $229,500
# 3                      2950    $336,638- $724,824     $650,000
# 4                      1890    $336,638- $724,824     $395,000
# ...                     ...                   ...          ...
# 8344                   2520    $336,638- $724,824     $610,685
# 8345                   3510  $710,003- $1,514,226   $1,010,000
# 8346                   1310    $336,638- $724,824     $475,000
# 8347                   2310    $336,638- $724,824     $400,000
# 8348                   1600    $336,638- $724,824     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Condition_Level=Prediction5
East_prediction_Condition_Level
# Out:
#       Condition Level           Prediction Actual Price
# 0                   3  $299,999 - $990,999     $221,900
# 1                   5  $299,999 - $990,999     $604,000
# 2                   3  $299,999 - $990,999     $229,500
# 3                   3  $299,999 - $990,999     $650,000
# 4                   3  $299,999 - $990,999     $395,000
# ...               ...                  ...          ...
# 8344                3  $299,999 - $990,999     $610,685
# 8345                3  $299,999 - $990,999   $1,010,000
# 8346                3  $299,999 - $990,999     $475,000
# 8347                3  $299,999 - $990,999     $400,000
# 8348                3  $299,999 - $990,999     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Year_Renoveted=Prediction4
East_prediction_Year_Renoveted
# Out:
#       Year Renoveted             Prediction Actual Price
# 0                0.0  $263,411 - $1,322,038     $221,900
# 1                0.0  $263,411 - $1,322,038     $604,000
# 2                0.0  $263,411 - $1,322,038     $229,500
# 3                0.0  $263,411 - $1,322,038     $650,000
# 4                0.0  $263,411 - $1,322,038     $395,000
# ...              ...                    ...          ...
# 8344             0.0  $263,411 - $1,322,038     $610,685
# 8345             0.0  $263,411 - $1,322,038   $1,010,000
# 8346             0.0  $263,411 - $1,322,038     $475,000
# 8347             0.0  $263,411 - $1,322,038     $400,000
# 8348             0.0  $263,411 - $1,322,038     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Year_Built=Prediction3
East_prediction_Year_Built
# Out:
#       Year Built             Prediction Actual Price
# 0           1955  $361,699 - $1,003,203     $221,900
# 1           1965  $361,699 - $1,003,203     $604,000
# 2           1960  $361,699 - $1,003,203     $229,500
# 3           1979  $361,699 - $1,003,203     $650,000
# 4           1994  $361,699 - $1,003,203     $395,000
# ...          ...                    ...          ...
# 8344        2014   $359,232- $1,216,998     $610,685
# 8345        2009   $359,232- $1,216,998   $1,010,000
# 8346        2008   $359,232- $1,216,998     $475,000
# 8347        2014   $359,232- $1,216,998     $400,000
# 8348        2004  $361,699 - $1,003,203     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Amount_of_Floors=Prediction2
East_prediction_Amount_of_Floors
# Out:
#       Amount of Floors             Prediction Actual Price
# 0                  1.0  $340,198 - $1,316,791     $221,900
# 1                  1.0  $340,198 - $1,316,791     $604,000
# 2                  1.0  $340,198 - $1,316,791     $229,500
# 3                  2.0  $340,198 - $1,316,791     $650,000
# 4                  2.0  $340,198 - $1,316,791     $395,000
# ...                ...                    ...          ...
# 8344               2.0  $340,198 - $1,316,791     $610,685
# 8345               2.0  $340,198 - $1,316,791   $1,010,000
# 8346               2.0  $340,198 - $1,316,791     $475,000
# 8347               2.0  $340,198 - $1,316,791     $400,000
# 8348               2.0  $340,198 - $1,316,791     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Amount_of_Bathrooms=Prediction1
East_prediction_Amount_of_Bathrooms
# Out:
#       Amount of Bathrooms             Prediction Actual Price
# 0                     1.0    $200,002 - $550,008     $221,900
# 1                     3.0  $536,188 - $1,612,980     $604,000
# 2                     1.0    $200,002 - $550,008     $229,500
# 3                     3.0  $536,188 - $1,612,980     $650,000
# 4                     2.0    $200,002 - $550,008     $395,000
# ...                   ...                    ...          ...
# 8344                  2.5    $200,002 - $550,008     $610,685
# 8345                  3.5  $536,188 - $1,612,980   $1,010,000
# 8346                  2.5    $200,002 - $550,008     $475,000
# 8347                  2.5    $200,002 - $550,008     $400,000
# 8348                  2.5    $200,002 - $550,008     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Amount_of_Bedrooms=Prediction
East_prediction_Amount_of_Bedrooms
# Out:
#       Amount of Bedrooms             Prediction Actual Price
# 0                      3   $210,001  - $633,508     $221,900
# 1                      4  $351,398 - $1,607,982     $604,000
# 2                      3   $210,001  - $633,508     $229,500
# 3                      4  $351,398 - $1,607,982     $650,000
# 4                      3   $210,001  - $633,508     $395,000
# ...                  ...                    ...          ...
# 8344                   4  $351,398 - $1,607,982     $610,685
# 8345                   4  $351,398 - $1,607,982   $1,010,000
# 8346                   3   $210,001  - $633,508     $475,000
# 8347                   4  $351,398 - $1,607,982     $400,000
# 8348                   3   $210,001  - $633,508     $400,000
#
# [8349 rows x 3 columns]

# %%
#East_predictions.reindex(g,method='bfill')

# %%
#pd.set_option('display.max_colwidth', 1000)

# %%
pd.set_option("display.max_columns", 100)

# %%
#East_predictions.style.set_properties(subset=['Bedrooms'], **{'width': '300px'})

# %%
pd.set_option("max_colwidth", 40)

# %%
df = pd.DataFrame({'text': ['foo foo foo foo foo foo foo foo', 'bar bar bar bar bar'],
                 'number': [1, 2]})

df.style.set_properties(subset=['text'], **{'width': '300px'})
# Out:
# <style  type="text/css" >
# #T_761bf_row0_col0,#T_761bf_row1_col0{
#             width:  300px;
#         }</style><table id="T_761bf_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >text</th>        <th class="col_heading level0 col1" >number</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_761bf_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_761bf_row0_col0" class="data row0 col0" >foo foo foo foo foo foo foo foo</td>
#                         <td id="T_761bf_row0_col1" class="data row0 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_761bf_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_761bf_row1_col0" class="data row1 col0" >bar bar bar bar bar</td>
#                         <td id="T_761bf_row1_col1" class="data row1 col1" >2</td>
#             </tr>
# ...

# %%
East_predictions
# Out:
#                   Id         Date               Bedrooms  \
# Quantile  Regression  Predictions   $210,001  - $633,508
# Quantile  Regression  Predictions  $351,398 - $1,607,982
# Quantile  Regression  Predictions   $210,001  - $633,508
# Quantile  Regression  Predictions  $351,398 - $1,607,982
# Quantile  Regression  Predictions   $210,001  - $633,508
# ...              ...          ...                    ...
# Quantile  Regression  Predictions  $351,398 - $1,607,982
# Quantile  Regression  Predictions  $351,398 - $1,607,982
# Quantile  Regression  Predictions   $210,001  - $633,508
# Quantile  Regression  Predictions  $351,398 - $1,607,982
# Quantile  Regression  Predictions   $210,001  - $633,508
#
#                       Bathrooms                 Floors             Year Built  \
# Quantile    $200,002 - $550,008  $340,198 - $1,316,791  $361,699 - $1,003,203
# Quantile  $536,188 - $1,612,980  $340,198 - $1,316,791  $361,699 - $1,003,203
# ...

# %%
# %store East_predictions
# Out:
# Stored 'East_predictions' (DataFrame)

# %%
df = pd.DataFrame({'points': [10, 12, 12, 14, 13, 18],
                   'rebounds': [7, 7, 8, 13, 7, 4],
                   'assists': [11, 8, 10, 6, 6, 5]})

# %%
df.loc['2'] = ['Regression','a3','b3' ]

# %%
df2 = pd.DataFrame({'Id':'Quantile Regression','Date':' Predictions',
                    'Bedrooms':bedrooms[0], 'Bathrooms':bathrooms[0], 
                    'Floors':floors[0], 'Year Built':yr_built[0], 
                    'Year Renoveted':yr_renovated[0],
            'Condition':condition[0], 'Sqft_living':sqft_living[0],'Sqft_lot':sqft_lot[0],
                          },index=[0])
df2
# Out:
#                     Id          Date  Bedrooms  Bathrooms  Floors  Year Built  \
# 0  Quantile Regression   Predictions         3        1.0     1.0        1955
#
#    Year Renoveted  Condition  Sqft_living  Sqft_lot
# 0             0.0          3         1180      5650

# %%
for i in [1,2,3,4]:
    #df2.append(house_info.iloc[[i]])
    house_info.append(East_predictions.iloc[[i]],ignore_index=True)
    #df.append(df2, ignore_index=True)
house_info.append(East_predictions)
# Out:
#                   Id         Date               Bedrooms  \
# 0         7129300520   10/13/2014                      3
# 1         2487200875    12/9/2014                      4
# 2         2414600126    4/15/2015                      3
# 3         9297300055    1/24/2015                      4
# 4         1875500060    7/31/2014                      3
# ...              ...          ...                    ...
# Quantile  Regression  Predictions  $351,398 - $1,607,982
# Quantile  Regression  Predictions  $351,398 - $1,607,982
# Quantile  Regression  Predictions   $210,001  - $633,508
# Quantile  Regression  Predictions  $351,398 - $1,607,982
# Quantile  Regression  Predictions   $210,001  - $633,508
#
#                       Bathrooms                 Floors             Year Built  \
# 0                           1.0                    1.0                   1955
# 1                           3.0                    1.0                   1965
# ...

# %%
house_info
# Out:
#               Id        Date  Bedrooms  Bathrooms  Floors  Year Built  \
# 0     7129300520  10/13/2014         3        1.0     1.0        1955
# 1     2487200875   12/9/2014         4        3.0     1.0        1965
# 2     2414600126   4/15/2015         3        1.0     1.0        1960
# 3     9297300055   1/24/2015         4        3.0     2.0        1979
# 4     1875500060   7/31/2014         3        2.0     2.0        1994
# ...          ...         ...       ...        ...     ...         ...
# 8344  3448900210  10/14/2014         4        2.5     2.0        2014
# 8345  7936000429   3/26/2015         4        3.5     2.0        2009
# 8346  2997800021   2/19/2015         3        2.5     2.0        2008
# 8347  6600060120   2/23/2015         4        2.5     2.0        2014
# 8348   291310100   1/16/2015         3        2.5     2.0        2004
#
#       Year Renoveted  Condition  Sqft_living  Sqft_lot
# 0                0.0          3         1180      5650
# ...

# %%
East_predictions
# Out:
#                    Bedrooms              Bathrooms                 Floors  \
# 0      $210,001  - $633,508    $200,002 - $550,008  $340,198 - $1,316,791
# 1     $351,398 - $1,607,982  $536,188 - $1,612,980  $340,198 - $1,316,791
# 2      $210,001  - $633,508    $200,002 - $550,008  $340,198 - $1,316,791
# 3     $351,398 - $1,607,982  $536,188 - $1,612,980  $340,198 - $1,316,791
# 4      $210,001  - $633,508    $200,002 - $550,008  $340,198 - $1,316,791
# ...                     ...                    ...                    ...
# 8344  $351,398 - $1,607,982    $200,002 - $550,008  $340,198 - $1,316,791
# 8345  $351,398 - $1,607,982  $536,188 - $1,612,980  $340,198 - $1,316,791
# 8346   $210,001  - $633,508    $200,002 - $550,008  $340,198 - $1,316,791
# 8347  $351,398 - $1,607,982    $200,002 - $550,008  $340,198 - $1,316,791
# 8348   $210,001  - $633,508    $200,002 - $550,008  $340,198 - $1,316,791
#
#                  Year Built        Years Renoveted            Condition  \
# ...

# %%
df.style.background_gradient()
# Out:
# <style  type="text/css" >
# </style><table id="T_e3f50_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >points</th>        <th class="col_heading level0 col1" >rebounds</th>        <th class="col_heading level0 col2" >assists</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e3f50_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e3f50_row0_col0" class="data row0 col0" >10</td>
#                         <td id="T_e3f50_row0_col1" class="data row0 col1" >7</td>
#                         <td id="T_e3f50_row0_col2" class="data row0 col2" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_e3f50_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e3f50_row1_col0" class="data row1 col0" >12</td>
#                         <td id="T_e3f50_row1_col1" class="data row1 col1" >7</td>
# ...

# %%
df.style.set_properties(**{'border': '5px solid lawngreen',
                          'color': 'magenta'})
# Out:
# <style  type="text/css" >
# #T_8e603_row0_col0,#T_8e603_row0_col1,#T_8e603_row0_col2,#T_8e603_row1_col0,#T_8e603_row1_col1,#T_8e603_row1_col2,#T_8e603_row2_col0,#T_8e603_row2_col1,#T_8e603_row2_col2,#T_8e603_row3_col0,#T_8e603_row3_col1,#T_8e603_row3_col2,#T_8e603_row4_col0,#T_8e603_row4_col1,#T_8e603_row4_col2,#T_8e603_row5_col0,#T_8e603_row5_col1,#T_8e603_row5_col2,#T_8e603_row6_col0,#T_8e603_row6_col1,#T_8e603_row6_col2{
#             border:  5px solid lawngreen;
#             color:  magenta;
#         }</style><table id="T_8e603_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >points</th>        <th class="col_heading level0 col1" >rebounds</th>        <th class="col_heading level0 col2" >assists</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8e603_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8e603_row0_col0" class="data row0 col0" >10</td>
# ...

# %%
df1 =df.style.set_properties(**{'font-size': '15pt','border': '5px solid green',
                          'color': 'magenta','selector': 'th', 'props': [('font-size', '15pt')],
                          })
df1
# Out:
# <style  type="text/css" >
# #T_6719f_row0_col0,#T_6719f_row0_col1,#T_6719f_row0_col2,#T_6719f_row1_col0,#T_6719f_row1_col1,#T_6719f_row1_col2,#T_6719f_row2_col0,#T_6719f_row2_col1,#T_6719f_row2_col2,#T_6719f_row3_col0,#T_6719f_row3_col1,#T_6719f_row3_col2,#T_6719f_row4_col0,#T_6719f_row4_col1,#T_6719f_row4_col2,#T_6719f_row5_col0,#T_6719f_row5_col1,#T_6719f_row5_col2,#T_6719f_row6_col0,#T_6719f_row6_col1,#T_6719f_row6_col2{
#             font-size:  15pt;
#             border:  5px solid green;
#             color:  magenta;
#             selector:  th;
#             props:  [('font-size', '15pt')];
#         }</style><table id="T_6719f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >points</th>        <th class="col_heading level0 col1" >rebounds</th>        <th class="col_heading level0 col2" >assists</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %%
df1 =df.style.set_table_styles([{'selector': 'th', 'props': [('font-size', '15pt')],}])       
df1
# Out:
# <style  type="text/css" >
#     #T_df65b_ th {
#           font-size: 15pt;
#     }</style><table id="T_df65b_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >points</th>        <th class="col_heading level0 col1" >rebounds</th>        <th class="col_heading level0 col2" >assists</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_df65b_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_df65b_row0_col0" class="data row0 col0" >10</td>
#                         <td id="T_df65b_row0_col1" class="data row0 col1" >7</td>
#                         <td id="T_df65b_row0_col2" class="data row0 col2" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_df65b_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_df65b_row1_col0" class="data row1 col0" >12</td>
# ...

# %%
def style_negative(v, props=''):
    return props if v < 0 else None
df.style.applymap(style_negative, props='color:red;')\
              .applymap(lambda v: 'opacity: 20%;' if (v < 0.3) and (v > -0.3) else None)
# Out:
# <style  type="text/css" >
# #T_40f2f_row0_col3,#T_40f2f_row0_col4,#T_40f2f_row1_col1,#T_40f2f_row1_col2,#T_40f2f_row2_col1,#T_40f2f_row5_col1,#T_40f2f_row7_col3,#T_40f2f_row8_col2,#T_40f2f_row8_col4,#T_40f2f_row9_col3{
#             color: red;
#         }#T_40f2f_row1_col4,#T_40f2f_row2_col2,#T_40f2f_row3_col2,#T_40f2f_row4_col3,#T_40f2f_row6_col1{
#             opacity:  20%;
#         }#T_40f2f_row5_col4,#T_40f2f_row6_col3,#T_40f2f_row9_col1{
#             color: red;
#             opacity:  20%;
#         }</style><table id="T_40f2f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40f2f_level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
df3 = pd.DataFrame(np.random.randn(4,4),
                   pd.MultiIndex.from_product([['A', 'B'], ['r1', 'r2']]),
                   columns=['c1','c2','c3','c4'])
df3
# Out:
#             c1        c2        c3        c4
# A r1  1.264103  0.290035 -1.970288  0.803906
#   r2  1.030550  0.118098 -0.021853  0.046841
# B r1 -1.628753 -0.392361  1.700973  1.061330
#   r2  0.695804 -0.435989 -0.332942  0.602135

# %%
df.style.set_table_styles([{'selector': 'tr:hover', 'props': [('background-color', 'grey')]}])
# Out:
# <style  type="text/css" >
#     #T_5896f_ tr:hover {
#           background-color: grey;
#     }</style><table id="T_5896f_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >points</th>        <th class="col_heading level0 col1" >rebounds</th>        <th class="col_heading level0 col2" >assists</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_5896f_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_5896f_row0_col0" class="data row0 col0" >10</td>
#                         <td id="T_5896f_row0_col1" class="data row0 col1" >7</td>
#                         <td id="T_5896f_row0_col2" class="data row0 col2" >11</td>
#             </tr>
#             <tr>
#                         <th id="T_5896f_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_5896f_row1_col0" class="data row1 col0" >12</td>
# ...

# %%
import pandas as pd
import numpy as np
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan
df.iloc[3, 3] = np.nan
df.iloc[4, 1] = np.nan
df.iloc[9, 4] = np.nan
print("Original array:")
print(df)
print("\nDataframe - table style:")
# Set CSS properties for th elements in dataframe
th_props = [
  ('font-size', '30px'),
  ('text-align', 'center'),
  ('font-weight', 'bold'),
  ('color', 'black'),
  ('background-color', 'blue'),
  ('border','10px red'),
  ('hover','grey')
  ]

# Set CSS properties for td elements in dataframe
td_props = [
  ('font-size', '30px'),
   ('background-color','grey'),
    ('color','black'),
    ('border','10px red'),
    
  ]

# Set table styles
styles = [
  dict(selector="th", props=th_props),
  dict(selector="td", props=td_props)
  ]
(df.style
        .set_table_styles(styles))
# Out:
# Original array:
#       A         B         C         D         E
# 0   1.0  1.329212       NaN -0.316280 -0.990810
# 1   2.0 -1.070816 -1.438713  0.564417  0.295722
# 2   3.0 -1.626404  0.219565  0.678805  1.889273
# 3   4.0  0.961538  0.104011       NaN  0.850229
# 4   5.0       NaN  1.057737  0.165562  0.515018
# 5   6.0 -1.336936  0.562861  1.392855 -0.063328
# 6   7.0  0.121668  1.207603 -0.002040  1.627796
# 7   8.0  0.354493  1.037528 -0.385684  0.519818
# 8   9.0  1.686583 -1.325963  1.428984 -2.089354
# 9  10.0 -0.129820  0.631523 -0.586538       NaN
#
# Dataframe - table style:
# <style  type="text/css" >
#     #T_47c13_ th {
#           font-size: 30px;
#           text-align: center;
#           font-weight: bold;
#           color: black;
#           background-color: blue;
#           border: 10px red;
#           hover: grey;
#     }    #T_47c13_ td {
#           font-size: 30px;
#           background-color: grey;
#           color: black;
# ...
