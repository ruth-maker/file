# %%
import pandas as pd

# %%
# %store -r raw_info

# %%
raw_info
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
raw_info['yr_renovated'] = raw_info['yr_renovated'].fillna(0)

# %%
locationzip =raw_info.zipcode
locationzip
# Out:
# 0        98178
# 1        98125
# 2        98028
# 3        98136
# 4        98074
#          ...
# 21592    98103
# 21593    98146
# 21594    98144
# 21595    98027
# 21596    98144
# Name: zipcode, Length: 21597, dtype: int64

# %%
select= [98178,98199,98106,98072,98075,98019,98116,98106,98178,98108,98199,98056,98136,98065,98040,98029,
98006,98024,98106,98059,98034,98118,98056,98029,98119,98199,98199,98040,98034,98006,98006,98146,
98106,98072,98052,98126,98108,98199,98059,98118,98118,98122,98027,98027,98004,98199]

# %%
index2 = []
for x,i in enumerate(raw_info.zipcode):
        if i == select[0] : index2.append(x)
        elif i == select[1] : index2.append(x)
        elif i == select[2] : index2.append(x)
        elif i == select[3] : index2.append(x)
        elif i == select[4] : index2.append(x)
        elif i == select[5] : index2.append(x)
        elif i == select[6] : index2.append(x)
        elif i == select[7] : index2.append(x)
        elif i == select[8] : index2.append(x)
        elif i == select[9] : index2.append(x)
        elif i == select[10] : index2.append(x)
        elif i == select[11] : index2.append(x)
        elif i == select[12] : index2.append(x)
        elif i == select[13] : index2.append(x)
        elif i == select[14] : index2.append(x)
        elif i == select[15] : index2.append(x)
        elif i == select[16] : index2.append(x)
        elif i == select[17] : index2.append(x)
        elif i == select[18] : index2.append(x)
        elif i == select[19] : index2.append(x)
        elif i == select[20] : index2.append(x)
        elif i == select[21]: index2.append(x)
        elif i == select[22] : index2.append(x)
        elif i == select[23] : index2.append(x)
        elif i == select[24] : index2.append(x)
        elif i == select[25] : index2.append(x)
        elif i == select[26] : index2.append(x)
        elif i == select[27] : index2.append(x)
        elif i == select[28] : index2.append(x)
        elif i == select[29] : index2.append(x)
        elif i == select[30] : index2.append(x)
        elif i == select[31] : index2.append(x)
        elif i == select[32] : index2.append(x)
        elif i == select[33] : index2.append(x)
        elif i == select[34] : index2.append(x)
        elif i == select[35] : index2.append(x)
        elif i == select[36] : index2.append(x)
        elif i == select[37] : index2.append(x)
        elif i == select[38] : index2.append(x)
        elif i == select[39] : index2.append(x)
        elif i == select[40] : index2.append(x)
        elif i == select[41] : index2.append(x)
        elif i == select[42] : index2.append(x)
        elif i == select[43] : index2.append(x)
        elif i == select[44] : index2.append(x)
        elif i == select[45] : index2.append(x)
len(index2)
# %store index2
# Out:
# Stored 'index2' (list)

# %%
id = []
for i in index2:
    id.append(raw_info.id[i])
len(id)
# Out:
# 8349

# %%
date = []
for i in index2:
    date.append(raw_info.date[i])
len(date)
# Out:
# 8349

# %%
bedrooms = []
for i in index2:
    bedrooms.append(raw_info.bedrooms[i])
len(bedrooms)
# Out:
# 8349

# %%
bathrooms = []
for i in index2:
    bathrooms.append(raw_info.bathrooms[i])
len(bathrooms)
# Out:
# 8349

# %%
sqft_living = []
for i in index2:
    sqft_living.append(raw_info.sqft_living[i])
len(sqft_living)
# Out:
# 8349

# %%
sqft_lot = []
for i in index2:
    sqft_lot.append(raw_info.sqft_lot[i])
len(sqft_lot)
# Out:
# 8349

# %%
floors = []
for i in index2:
    floors.append(raw_info.floors[i])
len(floors)
# Out:
# 8349

# %%
yr_built = []
for i in index2:
    yr_built.append(raw_info.yr_built[i])
len(yr_built)
# Out:
# 8349

# %%
yr_renovated = []
for i in index2:
    yr_renovated.append(raw_info.yr_renovated[i])
len(yr_renovated)
# Out:
# 8349

# %%
condition = []
for i in index2:
    condition.append(raw_info.condition[i])
len(condition)
# Out:
# 8349

# %%
g = []
for i in range(8349):
    g.append('Quantile')

# %%
x = []
for i in range(8349):
    x.append('Regression')

# %%
w = []
for i in range(8349):
    w.append('Weighted')

# %%
a = []
for i in range(8349):
    a.append('Average')

# %%
f = []
for i in range(8349):
    f.append('Predictions')

# %%
house_info = pd.DataFrame({'Id':id,'Date':date,'Bedrooms':bedrooms, 'Bathrooms':bathrooms, 
                           'Floors':floors, 'Year Built':yr_built, 'Year Renoveted':yr_renovated,
            'Condition':condition, 'Sqft_living':sqft_living,'Sqft_lot':sqft_lot,
                          })
house_info
# Out:
#               Id        Date  Bedrooms  Bathrooms  Floors  Year Built  \
# 0     7129300520  10/13/2014         3        1.0     1.0        1955
# 1     2487200875   12/9/2014         4        3.0     1.0        1965
# 2     2414600126   4/15/2015         3        1.0     1.0        1960
# 3     9297300055   1/24/2015         4        3.0     2.0        1979
# 4     1875500060   7/31/2014         3        2.0     2.0        1994
# ...          ...         ...       ...        ...     ...         ...
# 8344  3448900210  10/14/2014         4        2.5     2.0        2014
# 8345  7936000429   3/26/2015         4        3.5     2.0        2009
# 8346  2997800021   2/19/2015         3        2.5     2.0        2008
# 8347  6600060120   2/23/2015         4        2.5     2.0        2014
# 8348   291310100   1/16/2015         3        2.5     2.0        2004
#
#       Year Renoveted  Condition  Sqft_living  Sqft_lot
# 0                0.0          3         1180      5650
# ...

# %%
# %store -r Quantile_Regression_Prediction8 
# %store -r Quantile_Regression_Prediction7 
# %store -r Quantile_Regression_Prediction5 
# %store -r Quantile_Regression_Prediction4
# %store -r Quantile_Regression_Prediction3
# %store -r Quantile_Regression_Prediction2
# %store -r Quantile_Regression_Prediction1
# %store -r Quantile_Regression_Prediction
# %store -r Weighted_Average_Prediction8 
# %store -r Weighted_Average_Prediction7 
# %store -r Weighted_Average_Prediction5 
# %store -r Weighted_Average_Prediction4
# %store -r Weighted_Average_Prediction3
# %store -r Weighted_Average_Prediction2
# %store -r Weighted_Average_Prediction1
# %store -r Weighted_Average_Prediction
# %store -r price
# %store -r house_info

# %%
East_prediction_sqft_lot= Quantile_Regression_Prediction8
East_prediction_sqft_lot
# Out:
#       Amount_of_sqft_lot Quantile_Regression_Prediction Actual Price
# 0                   5650            $201,558 - $939,876     $221,900
# 1                   5000            $201,558 - $939,876     $604,000
# 2                   7470            $201,558 - $939,876     $229,500
# 3                   5000            $201,558 - $939,876     $650,000
# 4                  14040            $201,558 - $939,876     $395,000
# ...                  ...                            ...          ...
# 8344                6023            $201,558 - $939,876     $610,685
# 8345                7200            $201,558 - $939,876   $1,010,000
# 8346                1294            $201,558 - $939,876     $475,000
# 8347                5813            $201,558 - $939,876     $400,000
# 8348                2388            $201,558 - $939,876     $400,000
#
# [8349 rows x 3 columns]

# %%
East_Weighted_Average_sqft_lot= Weighted_Average_Prediction8 
East_Weighted_Average_sqft_lot
# Out:
#       Amount_of_sqft_lot Weighted_Average_Prediction Actual Price
# 0                   5650                    $528,685     $221,900
# 1                   5000                    $528,685     $604,000
# 2                   7470                    $528,685     $229,500
# 3                   5000                    $528,685     $650,000
# 4                  14040                    $528,685     $395,000
# ...                  ...                         ...          ...
# 8344                6023                    $610,000     $610,685
# 8345                7200                    $318,500   $1,010,000
# 8346                1294                    $595,000     $475,000
# 8347                5813                    $912,000     $400,000
# 8348                2388                    $580,000     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_sqft_living= Quantile_Regression_Prediction7
East_prediction_sqft_living
# Out:
#       Amount_of_sqft_Living Quantile_Regression_Prediction Actual Price
# 0                      1180             $336,638- $724,824     $221,900
# 1                      1960             $336,638- $724,824     $604,000
# 2                      1780             $336,638- $724,824     $229,500
# 3                      2950             $336,638- $724,824     $650,000
# 4                      1890             $336,638- $724,824     $395,000
# ...                     ...                            ...          ...
# 8344                   2520             $336,638- $724,824     $610,685
# 8345                   3510           $710,003- $1,514,226   $1,010,000
# 8346                   1310             $336,638- $724,824     $475,000
# 8347                   2310             $336,638- $724,824     $400,000
# 8348                   1600             $336,638- $724,824     $400,000
#
# [8349 rows x 3 columns]

# %%
East_Weighted_Average_Amount_of_sqft_Living = Weighted_Average_Prediction7 
East_Weighted_Average_Amount_of_sqft_Living
# Out:
#       Amount_of_sqft_Living Weighted_Average_Prediction Actual Price
# 0                      1180                    $387,403     $221,900
# 1                      1960                    $470,676     $604,000
# 2                      1780                    $488,822     $229,500
# 3                      2950                    $765,034     $650,000
# 4                      1890                    $532,858     $395,000
# ...                     ...                         ...          ...
# 8344                   2520                    $656,487     $610,685
# 8345                   3510                    $872,158   $1,010,000
# 8346                   1310                    $363,025     $475,000
# 8347                   2310                    $678,408     $400,000
# 8348                   1600                    $451,349     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Condition_Level= Quantile_Regression_Prediction5
East_prediction_Condition_Level
# Out:
#       Condition Level Quantile_Regression_Prediction Actual Price
# 0                   3            $299,999 - $990,999     $221,900
# 1                   5            $299,999 - $990,999     $604,000
# 2                   3            $299,999 - $990,999     $229,500
# 3                   3            $299,999 - $990,999     $650,000
# 4                   3            $299,999 - $990,999     $395,000
# ...               ...                            ...          ...
# 8344                3            $299,999 - $990,999     $610,685
# 8345                3            $299,999 - $990,999   $1,010,000
# 8346                3            $299,999 - $990,999     $475,000
# 8347                3            $299,999 - $990,999     $400,000
# 8348                3            $299,999 - $990,999     $400,000
#
# [8349 rows x 3 columns]

# %%
East_Weighted_Average_Condition_Level = Weighted_Average_Prediction5
East_Weighted_Average_Condition_Level
# Out:
#       Condition Level Weighted_Average_Prediction Actual Price
# 0                   3                    $606,899     $221,900
# 1                   5                    $647,621     $604,000
# 2                   3                    $606,899     $229,500
# 3                   3                    $606,899     $650,000
# 4                   3                    $606,899     $395,000
# ...               ...                         ...          ...
# 8344                3                    $606,899     $610,685
# 8345                3                    $606,899   $1,010,000
# 8346                3                    $606,899     $475,000
# 8347                3                    $606,899     $400,000
# 8348                3                    $606,899     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Year_Renoveted=Quantile_Regression_Prediction4
East_prediction_Year_Renoveted
# Out:
#       Year Renoveted Quantile_Regression_Prediction Actual Price
# 0                0.0          $263,411 - $1,322,038     $221,900
# 1                0.0          $263,411 - $1,322,038     $604,000
# 2                0.0          $263,411 - $1,322,038     $229,500
# 3                0.0          $263,411 - $1,322,038     $650,000
# 4                0.0          $263,411 - $1,322,038     $395,000
# ...              ...                            ...          ...
# 8344             0.0          $263,411 - $1,322,038     $610,685
# 8345             0.0          $263,411 - $1,322,038   $1,010,000
# 8346             0.0          $263,411 - $1,322,038     $475,000
# 8347             0.0          $263,411 - $1,322,038     $400,000
# 8348             0.0          $263,411 - $1,322,038     $400,000
#
# [8349 rows x 3 columns]

# %%
East_Weighted_Average_Year_Renoveted = Weighted_Average_Prediction4
East_Weighted_Average_Year_Renoveted
# Out:
#       Year Renoveted Weighted_Average_Prediction Actual Price
# 0                0.0                    $600,432     $221,900
# 1                0.0                    $600,432     $604,000
# 2                0.0                    $600,432     $229,500
# 3                0.0                    $600,432     $650,000
# 4                0.0                    $600,432     $395,000
# ...              ...                         ...          ...
# 8344             0.0                    $600,432     $610,685
# 8345             0.0                    $600,432   $1,010,000
# 8346             0.0                    $600,432     $475,000
# 8347             0.0                    $600,432     $400,000
# 8348             0.0                    $600,432     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Year_Built=Quantile_Regression_Prediction3
East_prediction_Year_Built
# Out:
#       Year Built Quantile_Regression_Prediction Actual Price
# 0           1955          $361,699 - $1,003,203     $221,900
# 1           1965          $361,699 - $1,003,203     $604,000
# 2           1960          $361,699 - $1,003,203     $229,500
# 3           1979          $361,699 - $1,003,203     $650,000
# 4           1994          $361,699 - $1,003,203     $395,000
# ...          ...                            ...          ...
# 8344        2014           $359,232- $1,216,998     $610,685
# 8345        2009           $359,232- $1,216,998   $1,010,000
# 8346        2008           $359,232- $1,216,998     $475,000
# 8347        2014           $359,232- $1,216,998     $400,000
# 8348        2004          $361,699 - $1,003,203     $400,000
#
# [8349 rows x 3 columns]

# %%
East_Weighted_Average_Year_Built = Weighted_Average_Prediction3
East_Weighted_Average_Year_Built
# Out:
#       Year Built Weighted_Average_Prediction Actual Price
# 0           1955                    $484,755     $221,900
# 1           1965                    $553,073     $604,000
# 2           1960                    $550,011     $229,500
# 3           1979                    $600,587     $650,000
# 4           1994                    $632,657     $395,000
# ...          ...                         ...          ...
# 8344        2014                    $736,528     $610,685
# 8345        2009                    $583,143   $1,010,000
# 8346        2008                    $692,798     $475,000
# 8347        2014                    $736,528     $400,000
# 8348        2004                    $661,901     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Amount_of_Floors= Quantile_Regression_Prediction2
East_prediction_Amount_of_Floors
# Out:
#       Amount of Floors Quantile_Regression_Prediction Actual Price
# 0                  1.0          $340,198 - $1,316,791     $221,900
# 1                  1.0          $340,198 - $1,316,791     $604,000
# 2                  1.0          $340,198 - $1,316,791     $229,500
# 3                  2.0          $340,198 - $1,316,791     $650,000
# 4                  2.0          $340,198 - $1,316,791     $395,000
# ...                ...                            ...          ...
# 8344               2.0          $340,198 - $1,316,791     $610,685
# 8345               2.0          $340,198 - $1,316,791   $1,010,000
# 8346               2.0          $340,198 - $1,316,791     $475,000
# 8347               2.0          $340,198 - $1,316,791     $400,000
# 8348               2.0          $340,198 - $1,316,791     $400,000
#
# [8349 rows x 3 columns]

# %%
East_Weighted_Average_Amount_of_Floors = Weighted_Average_Prediction2
East_Weighted_Average_Amount_of_Floors
# Out:
#       Amount of Floors Weighted_Average_Prediction Actual Price
# 0                  1.0                    $503,324     $221,900
# 1                  1.0                    $503,324     $604,000
# 2                  1.0                    $503,324     $229,500
# 3                  2.0                    $720,587     $650,000
# 4                  2.0                    $720,587     $395,000
# ...                ...                         ...          ...
# 8344               2.0                    $720,587     $610,685
# 8345               2.0                    $720,587   $1,010,000
# 8346               2.0                    $720,587     $475,000
# 8347               2.0                    $720,587     $400,000
# 8348               2.0                    $720,587     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Amount_of_Bathrooms= Quantile_Regression_Prediction1
East_prediction_Amount_of_Bathrooms
# Out:
#       Amount of Bathrooms Quantile_Regression_Prediction Actual Price
# 0                     1.0            $200,002 - $550,008     $221,900
# 1                     3.0          $536,188 - $1,612,980     $604,000
# 2                     1.0            $200,002 - $550,008     $229,500
# 3                     3.0          $536,188 - $1,612,980     $650,000
# 4                     2.0            $200,002 - $550,008     $395,000
# ...                   ...                            ...          ...
# 8344                  2.5            $200,002 - $550,008     $610,685
# 8345                  3.5          $536,188 - $1,612,980   $1,010,000
# 8346                  2.5            $200,002 - $550,008     $475,000
# 8347                  2.5            $200,002 - $550,008     $400,000
# 8348                  2.5            $200,002 - $550,008     $400,000
#
# [8349 rows x 3 columns]

# %%
East_Weighted_Average_Amount_of_Bathrooms= Weighted_Average_Prediction1
East_Weighted_Average_Amount_of_Bathrooms
# Out:
#       Amount of Bathrooms Weighted_Average_Prediction Actual Price
# 0                     1.0                    $351,193     $221,900
# 1                     3.0                    $769,417     $604,000
# 2                     1.0                    $351,193     $229,500
# 3                     3.0                    $769,417     $650,000
# 4                     2.0                    $496,507     $395,000
# ...                   ...                         ...          ...
# 8344                  2.5                    $625,123     $610,685
# 8345                  3.5                    $951,673   $1,010,000
# 8346                  2.5                    $625,123     $475,000
# 8347                  2.5                    $625,123     $400,000
# 8348                  2.5                    $625,123     $400,000
#
# [8349 rows x 3 columns]

# %%
East_prediction_Amount_of_Bedrooms= Quantile_Regression_Prediction
East_prediction_Amount_of_Bedrooms
# Out:
#       Amount of Bedrooms Quantile_Regression_Prediction Actual Price
# 0                      3           $210,001  - $633,508     $221,900
# 1                      4          $351,398 - $1,607,982     $604,000
# 2                      3           $210,001  - $633,508     $229,500
# 3                      4          $351,398 - $1,607,982     $650,000
# 4                      3           $210,001  - $633,508     $395,000
# ...                  ...                            ...          ...
# 8344                   4          $351,398 - $1,607,982     $610,685
# 8345                   4          $351,398 - $1,607,982   $1,010,000
# 8346                   3           $210,001  - $633,508     $475,000
# 8347                   4          $351,398 - $1,607,982     $400,000
# 8348                   3           $210,001  - $633,508     $400,000
#
# [8349 rows x 3 columns]

# %%
East_Weighted_Average_Amount_of_Bedrooms= Weighted_Average_Prediction
East_Weighted_Average_Amount_of_Bedrooms
# Out:
#       Amount of Bedrooms Weighted_Average_Prediction Actual Price
# 0                      3                    $522,941     $221,900
# 1                      4                    $724,117     $604,000
# 2                      3                    $522,941     $229,500
# 3                      4                    $724,117     $650,000
# 4                      3                    $522,941     $395,000
# ...                  ...                         ...          ...
# 8344                   4                    $724,117     $610,685
# 8345                   4                    $724,117   $1,010,000
# 8346                   3                    $522,941     $475,000
# 8347                   4                    $724,117     $400,000
# 8348                   3                    $522,941     $400,000
#
# [8349 rows x 3 columns]

# %%
East_predictions = pd.DataFrame({'Id':x,
'Date':f,'Bedrooms':East_prediction_Amount_of_Bedrooms.Quantile_Regression_Prediction,
'Bathrooms':East_prediction_Amount_of_Bathrooms.Quantile_Regression_Prediction, 
'Floors':East_prediction_Amount_of_Floors.Quantile_Regression_Prediction,
'Year Built':East_prediction_Year_Built.Quantile_Regression_Prediction,
'Years Renoveted':East_prediction_Year_Renoveted.Quantile_Regression_Prediction,
'Condition':East_prediction_Condition_Level.Quantile_Regression_Prediction, 
'Sqft_living':East_prediction_sqft_living.Quantile_Regression_Prediction,
'Sqft_lot':East_prediction_sqft_lot.Quantile_Regression_Prediction})
East_predictions
# Out:
#               Id         Date               Bedrooms              Bathrooms  \
# 0     Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# 1     Regression  Predictions  $351,398 - $1,607,982  $536,188 - $1,612,980
# 2     Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# 3     Regression  Predictions  $351,398 - $1,607,982  $536,188 - $1,612,980
# 4     Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# ...          ...          ...                    ...                    ...
# 8344  Regression  Predictions  $351,398 - $1,607,982    $200,002 - $550,008
# 8345  Regression  Predictions  $351,398 - $1,607,982  $536,188 - $1,612,980
# 8346  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
# 8347  Regression  Predictions  $351,398 - $1,607,982    $200,002 - $550,008
# 8348  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
#
# ...

# %%
id1 = []
for i in range(8349):
    id1.append(id[i])
    id1.append(x[i])
    id1.append(w[i])
len(id1)
# Out:
# 25047

# %%
date1 = []
for i in range(8349):
    date1.append(date[i])
    date1.append(f[i])
    date1.append(a[i])
len(date1)
# Out:
# 25047

# %%
bedrooms1 = []
for i in range(8349):
    bedrooms1.append(bedrooms[i])
    bedrooms1.append(East_prediction_Amount_of_Bedrooms.Quantile_Regression_Prediction[i])
    bedrooms1.append(East_Weighted_Average_Amount_of_Bedrooms.Weighted_Average_Prediction[i])
len(bedrooms1)
# Out:
# 25047

# %%
bathrooms1 = []
for i in range(8349):
    bathrooms1.append(bathrooms[i])
    bathrooms1.append(East_prediction_Amount_of_Bathrooms.Quantile_Regression_Prediction[i])
    bathrooms1.append(East_Weighted_Average_Amount_of_Bathrooms.Weighted_Average_Prediction[i])
len(bathrooms1)
# Out:
# 25047

# %%
floors1 = []
for i in range(8349):
    floors1.append(floors[i])
    floors1.append(East_prediction_Amount_of_Floors.Quantile_Regression_Prediction[i])
    floors1.append(East_Weighted_Average_Amount_of_Floors.Weighted_Average_Prediction[i])
len(floors1)
# Out:
# 25047

# %%
yr_built1 = []
for i in range(8349):
    yr_built1.append(yr_built[i])
    yr_built1.append(East_prediction_Year_Built.Quantile_Regression_Prediction[i])
    yr_built1.append(East_Weighted_Average_Year_Built.Weighted_Average_Prediction[i])
len(yr_built1)
# Out:
# 25047

# %%
yr_renovated1 = []
for i in range(8349):
    yr_renovated1.append(yr_renovated[i])
    yr_renovated1.append(East_prediction_Year_Renoveted.Quantile_Regression_Prediction[i])
    yr_renovated1.append(East_Weighted_Average_Year_Renoveted.Weighted_Average_Prediction[i])
len(yr_renovated1)
# Out:
# 25047

# %%
condition1 = []
for i in range(8349):
    condition1.append(condition[i])
    condition1.append(East_prediction_Condition_Level.Quantile_Regression_Prediction[i])
    condition1.append(East_Weighted_Average_Condition_Level.Weighted_Average_Prediction[i])
len(condition1)
# Out:
# 25047

# %%
sqft_living1 = []
for i in range(8349):
    sqft_living1.append(sqft_living[i])
    sqft_living1.append(East_prediction_sqft_living.Quantile_Regression_Prediction[i])
    sqft_living1.append(East_Weighted_Average_Amount_of_sqft_Living.Weighted_Average_Prediction[i])
len(sqft_living1)
# Out:
# 25047

# %%
sqft_lot1 = []
for i in range(8349):
    sqft_lot1.append(sqft_lot[i])
    sqft_lot1.append(East_prediction_sqft_lot.Quantile_Regression_Prediction[i])
    sqft_lot1.append(East_Weighted_Average_sqft_lot.Weighted_Average_Prediction[i])
len(sqft_lot1)
# Out:
# 25047

# %%
no = []
for i in range(1,8350):
    no.append(i)

# %%
house_info1 = pd.DataFrame({'Id':id1,'Date':date1,'Bedrooms':bedrooms1, 'Bathrooms':bathrooms1, 
                           'Floors':floors1, 'Year Built':yr_built1, 'Year Renoveted':yr_renovated1,
            'Condition':condition1, 'Sqft_living':sqft_living1,'Sqft_lot':sqft_lot1,
                          },
    pd.MultiIndex.from_product([no, ['A', 'B','C']]),
                          )
# %store house_info1
house_info1['Year Renoveted'] = house_info1['Year Renoveted'].fillna(0)
house_info1[:65]
# Out:
# Stored 'house_info1' (DataFrame)
#               Id         Date               Bedrooms              Bathrooms  \
# 1  A  7129300520   10/13/2014                      3                      1
#    B  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
#    C    Weighted      Average               $522,941               $351,193
# 2  A  2487200875    12/9/2014                      4                      3
#    B  Regression  Predictions  $351,398 - $1,607,982  $536,188 - $1,612,980
# ...          ...          ...                    ...                    ...
# 21 A  2391600320    4/20/2015                      3                      1
#    B  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
#    C    Weighted      Average               $522,941               $351,193
# 22 A  9418400240   10/28/2014                      2                      1
#    B  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
#
# ...

# %%
import statistics

x = []
for i in range(8349):
    bed_pred = int(float(East_Weighted_Average_Amount_of_Bedrooms.Weighted_Average_Prediction[i].replace(',','').replace('$','')))
    bath_pred = int(float(East_Weighted_Average_Amount_of_Bathrooms.Weighted_Average_Prediction[i].replace(',','').replace('$','')))
    fl_pred = int(float(East_Weighted_Average_Amount_of_Floors.Weighted_Average_Prediction[i].replace(',','').replace('$','')))
    yb_pred = int(float(East_Weighted_Average_Year_Built.Weighted_Average_Prediction[i].replace(',','').replace('$','')))
    yr_pred = int(float(East_Weighted_Average_Year_Renoveted.Weighted_Average_Prediction[i].replace(',','').replace('$','')))
    Con_pred = int(float(East_Weighted_Average_Condition_Level.Weighted_Average_Prediction[i].replace(',','').replace('$','')))
    sliv_pred = int(float(East_Weighted_Average_Amount_of_sqft_Living.Weighted_Average_Prediction[i].replace(',','').replace('$','')))
    slot_pred = int(float(East_Weighted_Average_sqft_lot.Weighted_Average_Prediction[i].replace(',','').replace('$','')))
    final = [bed_pred,bath_pred,fl_pred,yb_pred,Con_pred,sliv_pred,slot_pred,yr_pred]
    x.append(final)
x
# Out:
# [[522941, 351193, 503324, 484755, 606899, 387403, 528685, 600432],
#  [724117, 769417, 503324, 553073, 647621, 470676, 528685, 600432],
#  [522941, 351193, 503324, 550011, 606899, 488822, 528685, 600432],
#  [724117, 769417, 720587, 600587, 606899, 765034, 528685, 600432],
#  [522941, 496507, 720587, 632657, 606899, 532858, 528685, 600432],
#  [522941, 731200, 503324, 582677, 606899, 831567, 528685, 600432],
#  [522941, 496520, 720587, 548417, 606899, 729748, 528685, 600432],
#  [724117, 625123, 720587, 654231, 606899, 659616, 528685, 600432],
#  [522941, 625123, 720587, 680247, 606899, 551305, 528685, 600432],
#  [724117, 351193, 503324, 1097467, 414406, 448700, 528685, 600432],
#  [724117, 625123, 720587, 808699, 606899, 664758, 528685, 600432],
#  [522941, 351193, 720587, 450303, 606899, 488746, 528685, 600432],
#  [522941, 625123, 720587, 680247, 606899, 841891, 528685, 600432],
#  [883041, 625123, 503324, 567241, 617713, 696607, 528685, 600432],
# ...

# %%
takeClosest = lambda num,collection:min(collection,key=lambda x:abs(x-num))
closest = []
for i in range(8349):
    closest.append(takeClosest(price[i],x[i]))

# %%
closest
# Out:
# [351193,
#  600432,
#  351193,
#  606899,
#  496507,
#  831567,
#  729748,
#  720587,
#  600432,
#  528685,
#  606899,
#  720587,
#  522941,
#  503324,
#  502925,
#  448700,
#  746829,
#  883041,
#  383212,
#  724117,
#  468363,
#  351193,
#  460762,
#  720587,
#  522941,
#  398709,
#  336602,
#  1058458,
#  874393,
#  986850,
#  496520,
#  600432,
#  479996,
#  301333,
#  382707,
#  484567,
#  776035,
#  782175,
#  503324,
#  528685,
#  635797,
#  741852,
#  522941,
#  606899,
#  528685,
#  503324,
#  398709,
#  1505000,
#  606899,
#  475515,
#  503324,
#  488822,
#  828443,
#  503324,
#  496507,
#  421805,
#  724117,
#  655835,
#  642416,
#  347703,
#  371812,
#  528685,
#  600432,
#  742076,
#  585181,
#  438822,
#  625123,
#  436181,
#  522941,
#  522941,
#  272719,
#  316371,
#  724117,
#  653951,
#  351193,
#  485377,
#  1141050,
#  522941,
#  716481,
#  340109,
#  503324,
#  329504,
#  479821,
#  351193,
#  256278,
#  265028,
#  351193,
#  484755,
#  421805,
#  694045,
# ...

# %%
final_prediction = []
for i in closest:
    final_prediction.append( "${:,.0f}". format(i))

# %%
for i in range(8349):
    print(i,closest[i],East_Weighted_Average_Amount_of_Bedrooms['Actual Price'][i])
# Out:
# 0 351193 $221,900
# 1 600432 $604,000
# 2 351193 $229,500
# 3 606899 $650,000
# 4 496507 $395,000
# 5 831567 $2,000,000
# 6 729748 $937,000
# 7 720587 $719,000
# 8 600432 $580,500
# 9 528685 $550,000
# 10 606899 $605,000
# 11 720587 $685,000
# 12 522941 $488,000
# 13 503324 $345,000
# 14 502925 $430,000
# 15 448700 $425,000
# 16 746829 $975,000
# 17 883041 $1,330,000
# 18 383212 $325,000
# 19 724117 $832,500
# 20 468363 $480,000
# 21 351193 $355,000
# 22 460762 $356,000
# 23 720587 $940,000
# 24 522941 $461,000
# 25 398709 $215,000
# 26 336602 $335,000
# 27 1058458 $1,100,000
# 28 874393 $905,000
# 29 986850 $1,090,000
# 30 496520 $470,000
# 31 600432 $597,750
# 32 479996 $329,950
# 33 301333 $205,425
# 34 382707 $391,500
# 35 484567 $445,000
# 36 776035 $770,000
# 37 782175 $1,450,000
# 38 503324 $445,000
# 39 528685 $430,000
# 40 635797 $660,500
# 41 741852 $784,000
# 42 522941 $453,246
# 43 606899 $665,000
# 44 528685 $527,700
# 45 503324 $500,000
# 46 398709 $430,000
# ...

# %%
subtraction_accurracy = []
for i in range(8349):
    subtraction_accurracy.append(closest[i]-price[i])

# %%
division_accurracy = []
for i in range(8349):
    division_accurracy.append(subtraction_accurracy[i]/price[i])

# %%
percentage_accurracy = []
for i in range(8349):
    percentage_accurracy.append(division_accurracy[i]*100)

# %%
abs_value = [] 
for i in range(8349):
    abs_value.append(abs(percentage_accurracy[i]))
abs_value
# Out:
# [58.266336187471836,
#  0.5907284768211921,
#  53.02527233115468,
#  6.630923076923077,
#  25.697974683544306,
#  58.42165,
#  22.118676627534686,
#  0.22072322670375522,
#  3.43359173126615,
#  3.875454545454545,
#  0.31388429752066116,
#  5.195182481751825,
#  7.160040983606557,
#  45.89101449275363,
#  16.959302325581397,
#  5.576470588235294,
#  23.402153846153848,
#  33.605939849624065,
#  17.911384615384616,
#  13.018978978978978,
#  2.424375,
#  1.072394366197183,
#  29.427528089887637,
#  23.341808510638298,
#  13.436225596529283,
#  85.4460465116279,
#  0.47820895522388057,
#  3.7765454545454546,
#  3.381988950276243,
#  9.463302752293579,
#  5.642553191489362,
#  0.44868255959849435,
#  45.47537505682679,
#  46.68759888036996,
#  2.245977011494253,
#  8.891460674157303,
#  0.7837662337662338,
#  46.05689655172414,
#  13.106516853932584,
#  22.95,
#  3.7400454201362607,
#  5.376020408163265,
#  15.376859365554246,
#  8.736992481203007,
#  0.18665908660223612,
# ...

# %%
percentage2_accurracy = []
for i in abs_value:
    if i > 100: percentage2_accurracy.append(int(i-200))
    else:percentage2_accurracy.append(int(100-i))

count = 0
for i in percentage2_accurracy:
    if  i == 60 or i > 60:
        count+=1
        
display(count/8349*100)  
display(percentage2_accurracy)
# Out:
# 90.65756378009343
# [41,
#  99,
#  46,
#  93,
#  74,
#  41,
#  77,
#  99,
#  96,
#  96,
#  99,
#  94,
#  92,
#  54,
#  83,
#  94,
#  76,
#  66,
#  82,
#  86,
#  97,
#  98,
#  70,
#  76,
#  86,
#  14,
#  99,
#  96,
#  96,
#  90,
#  94,
#  99,
#  54,
#  53,
#  97,
#  91,
#  99,
#  53,
#  86,
#  77,
#  96,
#  94,
#  84,
#  91,
#  99,
#  99,
#  92,
#  66,
#  93,
#  51,
#  2,
#  88,
#  92,
#  85,
#  81,
#  85,
#  89,
#  99,
#  95,
#  81,
#  96,
#  87,
#  98,
#  88,
#  99,
#  56,
#  78,
#  96,
#  87,
#  81,
#  70,
#  84,
#  86,
#  96,
#  82,
#  98,
#  75,
#  82,
#  95,
#  87,
#  99,
#  45,
#  98,
#  85,
#  77,
#  53,
#  99,
#  74,
#  66,
#  99,
#  77,
#  65,
#  51,
#  91,
#  77,
#  39,
#  54,
#  92,
#  77,
#  93,
#  99,
#  98,
#  96,
#  96,
#  91,
#  82,
#  85,
#  97,
#  -76,
#  56,
#  96,
#  95,
#  92,
#  99,
#  48,
#  53,
#  77,
#  94,
#  0,
#  97,
#  95,
#  95,
#  2,
#  64,
#  92,
#  85,
#  70,
#  89,
#  96,
#  60,
#  95,
#  94,
#  51,
#  62,
#  71,
#  99,
#  66,
#  95,
#  90,
#  90,
# ...

# %%
negative = []
positive = []
for x,i in enumerate(percentage2_accurracy):
    if i >= 70:positive.append(x)
    else:negative.append(x)
# %store negative
# %store positive
# Out:
# Stored 'negative' (list)
# Stored 'positive' (list)

# %%
final_percentage_accurracy = []
for i in percentage2_accurracy:
    final_percentage_accurracy.append( '{:d}%'. format(i))
final_percentage_accurracy
# Out:
# ['41%',
#  '99%',
#  '46%',
#  '93%',
#  '74%',
#  '41%',
#  '77%',
#  '99%',
#  '96%',
#  '96%',
#  '99%',
#  '94%',
#  '92%',
#  '54%',
#  '83%',
#  '94%',
#  '76%',
#  '66%',
#  '82%',
#  '86%',
#  '97%',
#  '98%',
#  '70%',
#  '76%',
#  '86%',
#  '14%',
#  '99%',
#  '96%',
#  '96%',
#  '90%',
#  '94%',
#  '99%',
#  '54%',
#  '53%',
#  '97%',
#  '91%',
#  '99%',
#  '53%',
#  '86%',
#  '77%',
#  '96%',
#  '94%',
#  '84%',
#  '91%',
#  '99%',
#  '99%',
#  '92%',
#  '66%',
#  '93%',
#  '51%',
#  '2%',
#  '88%',
#  '92%',
#  '85%',
#  '81%',
#  '85%',
#  '89%',
#  '99%',
#  '95%',
#  '81%',
#  '96%',
#  '87%',
#  '98%',
#  '88%',
#  '99%',
#  '56%',
#  '78%',
#  '96%',
#  '87%',
#  '81%',
#  '70%',
#  '84%',
#  '86%',
#  '96%',
#  '82%',
#  '98%',
#  '75%',
#  '82%',
#  '95%',
#  '87%',
#  '99%',
#  '45%',
#  '98%',
#  '85%',
#  '77%',
#  '53%',
#  '99%',
#  '74%',
#  '66%',
#  '99%',
#  '77%',
#  '65%',
#  '51%',
#  '91%',
#  '77%',
#  '39%',
#  '54%',
#  '92%',
#  '77%',
#  '93%',
# ...

# %%
house_info
# Out:
#        Bedrooms  Bathrooms  Floors  Year Built  Year Renoveted  \
# 0             3       1.00     1.0        1955             0.0
# 1             3       2.25     2.0        1951          1991.0
# 2             2       1.00     1.0        1933             NaN
# 3             4       3.00     1.0        1965             0.0
# 4             3       2.00     1.0        1987             0.0
# ...         ...        ...     ...         ...             ...
# 21592         3       2.50     3.0        2009             0.0
# 21593         4       2.50     2.0        2014             0.0
# 21594         2       0.75     2.0        2009             0.0
# 21595         3       2.50     2.0        2004             0.0
# 21596         2       0.75     2.0        2008             0.0
#
#       Size of Basement  Condition  Size of Above  Location     Price  \
# 0                  0.0          3           1180     98178  221900.0
# ...

# %%
house_info1
# Out:
#                 Id         Date               Bedrooms              Bathrooms  \
# 1    A  7129300520   10/13/2014                      3                      1
#      B  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
#      C    Weighted      Average               $522,941               $351,193
# 2    A  2487200875    12/9/2014                      4                      3
#      B  Regression  Predictions  $351,398 - $1,607,982  $536,188 - $1,612,980
# ...            ...          ...                    ...                    ...
# 8348 B  Regression  Predictions  $351,398 - $1,607,982    $200,002 - $550,008
#      C    Weighted      Average               $724,117               $625,123
# 8349 A   291310100    1/16/2015                      3                    2.5
#      B  Regression  Predictions   $210,001  - $633,508    $200,002 - $550,008
#      C    Weighted      Average               $522,941               $625,123
#
# ...

# %%
house_predictions = pd.DataFrame({'Id':id,'Date':date,'Bedrooms':bedrooms, 'Bathrooms':bathrooms, 
                           'Floors':floors, 'Year Built':yr_built, 'Year Renoveted':yr_renovated,
            'Condition':condition, 'Sqft_living':sqft_living,'Sqft_lot':sqft_lot,
            'Actual Price':East_Weighted_Average_Amount_of_Bedrooms['Actual Price'],
            'Predicted Price':final_prediction, 
             'Percentage Accuracy':final_percentage_accurracy
                          })
house_predictions
# Out:
#               Id        Date  Bedrooms  Bathrooms  Floors  Year Built  \
# 0     7129300520  10/13/2014         3        1.0     1.0        1955
# 1     2487200875   12/9/2014         4        3.0     1.0        1965
# 2     2414600126   4/15/2015         3        1.0     1.0        1960
# 3     9297300055   1/24/2015         4        3.0     2.0        1979
# 4     1875500060   7/31/2014         3        2.0     2.0        1994
# ...          ...         ...       ...        ...     ...         ...
# 8344  3448900210  10/14/2014         4        2.5     2.0        2014
# 8345  7936000429   3/26/2015         4        3.5     2.0        2009
# 8346  2997800021   2/19/2015         3        2.5     2.0        2008
# 8347  6600060120   2/23/2015         4        2.5     2.0        2014
# 8348   291310100   1/16/2015         3        2.5     2.0        2004
#
#       Year Renoveted  Condition  Sqft_living  Sqft_lot Actual Price  \
# ...

# %%
# %store house_predictions
# Out:
# Stored 'house_predictions' (DataFrame)
